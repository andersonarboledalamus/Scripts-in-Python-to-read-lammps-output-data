# %%
## Script para leer perfiles de densidad lineal y graficar para articulos cientificos

# %%
# Importacion de librerias

import numpy as np
import pandas as pd

from scipy.optimize import least_squares
from scipy import optimize
from scipy.optimize import curve_fit

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import cm

from mpl_toolkits.axes_grid1 import make_axes_locatable
from collections import OrderedDict

import os
from math import *
from matplotlib.ticker import MultipleLocator, AutoMinorLocator

# %% [markdown]
# **<font color=blue size=5>1. Basales**

# %%
#### PROCESO DE GRAFICACIÓN ####
x = np.array([1,2,3,4,5])
y_COOH = np.array([24.8830, 25.9157, 25.0127, 24.7667, 23.7877])
y_C7 = np.array([25.0821, 25.0149, 25.0735, 25.0536, 25.0169])
y_COO = np.array([37.9966, 40.4933, 38.1901, 36.7672, 37.7837])
y_NH2 = np.array([24.7466, 24.7337, 24.7683, 24.6792, 25.5549])
y_C6 = np.array([26.0116, 26.9887, 28.0286, 30.9304, 30.7899])
y_NH3 = np.array([28.9066, 30.1280, 30.2630, 31.1243, 31.1376])

#Todo= pd.DataFrame([x , y_COOH, y_C7, y_COO, y_NH2, y_C5]).T
###### Determinacion de la altura de la interfase

# %%
fig, ax = plt.subplots(figsize=(9,6))
plt.rcParams["font.family"] = 'Times New Roman'

ax.plot(x, y_C6, '-ok', label='$C_{6}CH_3*H_{2}O$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.plot(x, y_C7, '-or', label='$n-C_7*H_{2}O$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.plot(x, y_COOH, color='orange', marker='o', label='$n-C_{6}COOH*H_{2}O$', markersize=5, lw=2)
#plt.axvline(x_max_Na, color = 'y', linestyle='--')

ax.plot(x, y_COO, '-oc', label='$n-C_{6}COO^{-}*H_{2}O-Na^+$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.plot(x, y_NH2, color ='purple', marker='o', label='$n-C_{6}NH_2*H_{2}O$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.plot(x, y_NH3, color ='green', marker='o', label='$n-C_{6}NH_3^+*H_{2}O-Cl^-$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.legend(loc='best', fontsize=12)
ax.xaxis.set_minor_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(20000))
ax.tick_params(axis='both', labelsize=12, width=3)
#ax.yaxis.set_minor_locator(AutoMinorLocator())
#ax.set_xlim(0, 10)
ax.set_xticks([0,1,2,3,4,5,6])
#ax.set_yticks([20, 30, 40, 50, 60, 70, 80, 90])
ax.set_ylim(20, 60)
ax.set_xlabel('Simulation time in the production stage (ns)',  fontsize=16)
ax.set_ylabel('Barycenter height $H_{b}$ (basal 001) (Å)', fontsize=16)
fig.savefig("Basal_Height.png", dpi=800)
plt.show()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# **<font color=blue size=5>1. Borde**

# %%
#### PROCESO DE GRAFICACIÓN ####
x = np.array([1,2,3,4,5])
y_COOH = np.array([26.5140, 25.3274, 25.5992, 27.1776, 26.0751])
y_C7 = np.array([28.1302, 29.5980, 28.3312, 27.5690, 27.5733])
y_COO = np.array([31.9484, 32.9808, 33.9930, 35.0625, 37.3395])
y_NH2 = np.array([29.3569, 28.6665, 29.7573, 31.0444, 29.3975])
y_C6 = np.array([29.6649, 29.3234, 30.0972, 29.9397, 31.4041])
y_NH3 = np.array([34.0974, 33.6037, 35.1188, 34.5763, 34.3397])

#Todo= pd.DataFrame([x , y_COOH, y_C7, y_COO, y_NH2, y_C5]).T
###### Determinacion de la altura de la interfase

# %%
fig, ax = plt.subplots(figsize=(9,6))
plt.rcParams["font.family"] = 'Times New Roman'

ax.plot(x, y_C6, '-ok', label='$C_{6}CH_3*H_{2}O$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.plot(x, y_C7, '-or', label='$n-C_7*H_{2}O$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.plot(x, y_COOH, color='orange', marker='o', label='$n-C_{6}COOH*H_{2}O$', markersize=5, lw=2)
#plt.axvline(x_max_Na, color = 'y', linestyle='--')

ax.plot(x, y_COO, '-oc', label='$n-C_{6}COO^{-}*H_{2}O-Na^+$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.plot(x, y_NH2, color ='purple', marker='o', label='$n-C_{6}NH_2*H_{2}O$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.plot(x, y_NH3, color ='green', marker='o', label='$n-C_{6}NH_3^+*H_{2}O-Cl^-$', markersize=5, lw=2)
#plt.axvline(x = x_max_K, color = 'purple', linestyle='--')

ax.legend(loc='best', fontsize=12)
ax.xaxis.set_minor_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(20000))
ax.tick_params(axis='both', labelsize=12, width=3)
#ax.yaxis.set_minor_locator(AutoMinorLocator())
#ax.set_xlim(0, 10)
ax.set_xticks([0,1,2,3,4,5,6])
ax.set_ylim(20, 60)
ax.set_xlabel('Simulation time in the production stage (ns)',  fontsize=16)
ax.set_ylabel('Barycenter height $H_{b}$ (edge 010) (Å)', fontsize=16)
fig.savefig("Edge_Height.png", dpi=800)
plt.show()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
